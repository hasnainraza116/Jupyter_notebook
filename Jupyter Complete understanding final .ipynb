# %% [markdown]
# # ✨ Jupyter Notebook Shortcuts (Easy Guide)
#
# ## 🟦 Command Mode (when you press **Esc**)
#
# - `Enter`: enter edit mode
# - `Shift` + `Enter`: ▶️ run the selected cell, select below
# - `Ctrl` + `Enter`: ▶️ run the selected cell
# - `Alt` + `Enter`: ▶️ run the selected cell, ➕ add a new cell below
# - `Y`: change cell to code
# - `M`: change cell to markdown
# - `A`: insert cell above
# - `B`: insert cell below
# - `D`, `D` (press the key twice): 🗑️ delete the current cell
# - `Z`: undo cell deletion
# - `Shift` + `M`: merge selected cells, or current cell with cell below if only one cell is selected
# - `Ctrl` + `S`: 💾 save your notebook progress
# - `L`: 🔢 show or hide line numbers
# - `Shift` + `L`: 🔢 show or hide line numbers in all cells (when in command mode)
# - `Up` or `K`: select cell above
# - `Down` or `J`: select cell below
#
# ## 🟩 Edit Mode (when you press **Enter**)
#
# - `Esc`: enter command mode
# - `Shift` + `Enter`: ▶️ run the selected cell, select below
# - `Ctrl` + `Enter`: ▶️ run the selected cell
# - `Alt` + `Enter`: ▶️ run the selected cell, ➕ add a new cell below
# - `Ctrl` + `Shift` + `-`: split the cell at cursor
# - `Ctrl` + `Z`: undo last text edit
# - `Ctrl` + `Shift` + `Z` or `Ctrl` + `Y`: redo last text edit
# - `Ctrl` + `Home`: go to cell start
# - `Ctrl` + `End`: go to cell end
# - `Ctrl` + `Left`: go one word left
# - `Ctrl` + `Right`: go one word right
# - `Ctrl` + `Backspace`: delete word before
# - `Ctrl` + `Delete`: delete word after
# - `Tab`: code completion or indent
# - `Shift` + `Tab`: tooltip
# - `Ctrl` + `]`: indent
# - `Ctrl` + `[`: dedent
# - `Ctrl` + `A`: select all
# - `Ctrl` + `Shift` + `K`: comment out the selected lines

# %% [markdown]
# # 🛠️ Useful Tools in Jupyter

# %% [markdown]
# ## 💻 Running Jupyter from the Command Line

# %%
# !pwd
#Fow windows command is !cd
# Out:
# /Users/hasnain

# %%
# !ls
# For windows  use !dir
# Out:
# Applications
# Desktop
# Documents
# Downloads
# End to End Jupyter notebook understanding.ipynb
# Jupyter Complete understanding .ipynb
# Library
# Local Sites
# ML_Series
# MovieRaterApi
# Movies
# Music
# New Udemy LLM course 190125.xlsx
# Pictures
# Postman
# Public
# PycharmProjects
# add.py
# anaconda_projects
# grafana-enterprise-12.0.2.darwin-amd64.tar.gz
# grafana-v12.0.2
# jupyter-beginners-guide.ipynb
# jupyter-easy-guide.ipynb
# jupyter-tips-and-tricks.ipynb.ipynb
# langchain_Eden_marco
# myenv
# projects
# student
# untitled folder 2
# x.txt
# ~$New Udemy LLM course 190125.xlsx

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /Users/hasnain/.git/

# %%
# !pip install pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Display all the rows and columns

# %%
import pandas as pd

df = pd.read_csv('/Users/hasnain/Downloads/ElectricCarData_Clean.csv')

df
# Out:
#            Brand                            Model  AccelSec  TopSpeed_KmH  \
# 0         Tesla     Model 3 Long Range Dual Motor       4.6           233
# 1    Volkswagen                         ID.3 Pure      10.0           160
# 2      Polestar                                 2       4.7           210
# 3           BMW                              iX3        6.8           180
# 4         Honda                                e        9.5           145
# ..           ...                              ...       ...           ...
# 98       Nissan                       Ariya 63kWh       7.5           160
# 99         Audi     e-tron S Sportback 55 quattro       4.5           210
# 100      Nissan               Ariya e-4ORCE 63kWh       5.9           200
# 101      Nissan   Ariya e-4ORCE 87kWh Performance       5.1           200
# 102       Byton                 M-Byte 95 kWh 2WD       7.5           190
#
#      Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
df
# Out:
#            Brand                            Model  AccelSec  TopSpeed_KmH  \
# 0         Tesla     Model 3 Long Range Dual Motor       4.6           233
# 1    Volkswagen                         ID.3 Pure      10.0           160
# 2      Polestar                                 2       4.7           210
# 3           BMW                              iX3        6.8           180
# 4         Honda                                e        9.5           145
# 5         Lucid                              Air        2.8           250
# 6    Volkswagen                           e-Golf        9.6           150
# 7       Peugeot                            e-208        8.1           150
# 8         Tesla       Model 3 Standard Range Plus       5.6           225
# 9          Audi                        Q4 e-tron        6.3           180
# 10     Mercedes                    EQC 400 4MATIC       5.1           180
# 11       Nissan                             Leaf        7.9           144
# ...

# %%
pd.set_option('display.max_rows', 20)

# %%
df
# Out:
#            Brand                            Model  AccelSec  TopSpeed_KmH  \
# 0         Tesla     Model 3 Long Range Dual Motor       4.6           233
# 1    Volkswagen                         ID.3 Pure      10.0           160
# 2      Polestar                                 2       4.7           210
# 3           BMW                              iX3        6.8           180
# 4         Honda                                e        9.5           145
# ..           ...                              ...       ...           ...
# 98       Nissan                       Ariya 63kWh       7.5           160
# 99         Audi     e-tron S Sportback 55 quattro       4.5           210
# 100      Nissan               Ariya e-4ORCE 63kWh       5.9           200
# 101      Nissan   Ariya e-4ORCE 87kWh Performance       5.1           200
# 102       Byton                 M-Byte 95 kWh 2WD       7.5           190
#
#      Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# ...

# %%
df = pd.read_csv('/Users/hasnain/Downloads/ElectricCarData_Clean.csv')
df
# Out:
#            Brand                            Model  AccelSec  TopSpeed_KmH  \
# 0         Tesla     Model 3 Long Range Dual Motor       4.6           233
# 1    Volkswagen                         ID.3 Pure      10.0           160
# 2      Polestar                                 2       4.7           210
# 3           BMW                              iX3        6.8           180
# 4         Honda                                e        9.5           145
# ..           ...                              ...       ...           ...
# 98       Nissan                       Ariya 63kWh       7.5           160
# 99         Audi     e-tron S Sportback 55 quattro       4.5           210
# 100      Nissan               Ariya e-4ORCE 63kWh       5.9           200
# 101      Nissan   Ariya e-4ORCE 87kWh Performance       5.1           200
# 102       Byton                 M-Byte 95 kWh 2WD       7.5           190
#
#      Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#            Brand                            Model  AccelSec  TopSpeed_KmH  \
# 0         Tesla     Model 3 Long Range Dual Motor       4.6           233
# 1    Volkswagen                         ID.3 Pure      10.0           160
# 2      Polestar                                 2       4.7           210
# 3           BMW                              iX3        6.8           180
# 4         Honda                                e        9.5           145
# ..           ...                              ...       ...           ...
# 98       Nissan                       Ariya 63kWh       7.5           160
# 99         Audi     e-tron S Sportback 55 quattro       4.5           210
# 100      Nissan               Ariya e-4ORCE 63kWh       5.9           200
# 101      Nissan   Ariya e-4ORCE 87kWh Performance       5.1           200
# 102       Byton                 M-Byte 95 kWh 2WD       7.5           190
#
#      Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# ...

# %%
pd.set_option('display.max_columns', 10)

# %%
df
# Out:
#            Brand                            Model  AccelSec  TopSpeed_KmH  \
# 0         Tesla     Model 3 Long Range Dual Motor       4.6           233
# 1    Volkswagen                         ID.3 Pure      10.0           160
# 2      Polestar                                 2       4.7           210
# 3           BMW                              iX3        6.8           180
# 4         Honda                                e        9.5           145
# ..           ...                              ...       ...           ...
# 98       Nissan                       Ariya 63kWh       7.5           160
# 99         Audi     e-tron S Sportback 55 quattro       4.5           210
# 100      Nissan               Ariya e-4ORCE 63kWh       5.9           200
# 101      Nissan   Ariya e-4ORCE 87kWh Performance       5.1           200
# 102       Byton                 M-Byte 95 kWh 2WD       7.5           190
#
#      Range_Km  ...    PlugType  BodyStyle Segment Seats PriceEuro
# ...

# %% [markdown]
# ## Supress Warning

# %%
import pandas as pd

# Creating a DataFrame
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})

# Trying to modify a slice of the DataFrame directly
subset = df[df['A'] > 1]
subset['B'] = subset['B'] + 1
# Out:
# /var/folders/cy/n785kpzx0mqbf82508jmczlc0000gp/T/ipykernel_2694/98024902.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['B'] = subset['B'] + 1

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Print all variable

# %%
df = pd.read_csv('/Users/hasnain/Downloads/ElectricCarData_Clean.csv')

# %%
df.describe()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Brand            103 non-null    object
#  1   Model            103 non-null    object
#  2   AccelSec         103 non-null    float64
#  3   TopSpeed_KmH     103 non-null    int64
#  4   Range_Km         103 non-null    int64
#  5   Efficiency_WhKm  103 non-null    int64
#  6   FastCharge_KmH   103 non-null    object
#  7   RapidCharge      103 non-null    object
#  8   PowerTrain       103 non-null    object
#  9   PlugType         103 non-null    object
#  10  BodyStyle        103 non-null    object
#  11  Segment          103 non-null    object
#  12  Seats            103 non-null    int64
#  13  PriceEuro        103 non-null    int64
# dtypes: float64(1), int64(5), object(8)
# memory usage: 11.4+ KB

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
df.describe()
df.info()
a=2
a
# Out:
#          AccelSec  TopSpeed_KmH    Range_Km  Efficiency_WhKm       Seats  \
# count  103.000000    103.000000  103.000000       103.000000  103.000000
# mean     7.396117    179.194175  338.786408       189.165049    4.883495
# std      3.017430     43.573030  126.014444        29.566839    0.795834
# min      2.100000    123.000000   95.000000       104.000000    2.000000
# 25%      5.100000    150.000000  250.000000       168.000000    5.000000
# 50%      7.300000    160.000000  340.000000       180.000000    5.000000
# 75%      9.000000    200.000000  400.000000       203.000000    5.000000
# max     22.400000    410.000000  970.000000       273.000000    7.000000
#
#            PriceEuro
# count     103.000000
# mean    55811.563107
# std     34134.665280
# min     20129.000000
# 25%     34429.500000
# 50%     45000.000000
# 75%     65000.000000
# max    215000.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 14 columns):
# ...

# %% [markdown]
# ## Print output of any other cell

# %%
Out[]
# Out:
#   Cell In[58], line 1
#     Out[]
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Close long output

# %%
Out[22]
# Out:
#            Brand                            Model  AccelSec  TopSpeed_KmH  \
# 0         Tesla     Model 3 Long Range Dual Motor       4.6           233
# 1    Volkswagen                         ID.3 Pure      10.0           160
# 2      Polestar                                 2       4.7           210
# 3           BMW                              iX3        6.8           180
# 4         Honda                                e        9.5           145
# ..           ...                              ...       ...           ...
# 98       Nissan                       Ariya 63kWh       7.5           160
# 99         Audi     e-tron S Sportback 55 quattro       4.5           210
# 100      Nissan               Ariya e-4ORCE 63kWh       5.9           200
# 101      Nissan   Ariya e-4ORCE 87kWh Performance       5.1           200
# 102       Byton                 M-Byte 95 kWh 2WD       7.5           190
#
#      Range_Km  ...    PlugType  BodyStyle Segment Seats PriceEuro
# ...

# %% [markdown]
# ## Remove extra output

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [4, 5, 6])

# %%
plt.plot([1, 2, 3], [4, 5, 6]);

# %% [markdown]
# # Magic Commands
#
# **%** is used for **line magics**. Line magic commands apply only to the rest of the line on which they are used.
#
# **%%** is used for **cell magics**. Cell magic commands apply to the entire cell in which they are the first line. This means that everything below the %% command (up to the end of the cell) is considered part of the command. Cell magics allow you to write more complex or multi-line commands, affecting or transforming the entire cell's content.

# %% [markdown]
# ## %time

# %%
# Example of using %time for a single line of code
# %time sum(range(1000000))
# Out:
# CPU times: user 34.8 ms, sys: 1.59 ms, total: 36.4 ms
# Wall time: 43.3 ms
# 499999500000

# %%
# %%time
# Example of using %%time for an entire cell
total = 0
for i in range(1000000):
    total += i
print(total)
# Out:
# 499999500000
# CPU times: user 226 ms, sys: 9.21 ms, total: 235 ms
# Wall time: 560 ms

# %%
# %timeit sum(range(1000000))
# Out:
# 61.9 ms ± 20.3 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ## %run

# %%
# %run add.py
# Out:
# This is the output 71

# %% [markdown]
# ## %% writefile

# %%
# %%writefile filename1.txt
#
# Hello, I am learning Jupyter note book complete hands on tuturial from technical skills academy.
# And this is the second line
# Out:
# Writing filename1.txt

# %%
# %%writefile hello_world.py

def hello_world():
    print("Hello, world!")

if __name__ == "__main__":
    hello_world()
# Out:
# Writing hello_world.py

# %%
# %run hello_world.py

# %% [markdown]
# ## %%html

# %%
# %%html
# <div style="color: red; font-size: 20px;">Hello, world!</div>
# Out:
# <div style="color: red; font-size: 20px;">Hello, world!</div>

# %%
url = "https://media.istockphoto.com/id/2217030312/photo/ai-agent-machine-learning-concepts-ai-artificial-intelligence-head-shape-on-abstract-cpu.jpg?s=1024x1024&w=is&k=20&c=R6qdphoq1q3UHsQymAYec8b6EaYPvm12QJiTU_em4YY="

#shortener the url

# %%
# %%html
# <img src="https://rb.gy/kmrja1" alt="Sample Image" width="300">
# Out:
# <img src="https://rb.gy/kmrja1" alt="Sample Image" width="300">

# %%
# %%html
# <table border="1">
#   <tr>
#     <th>Firstname</th>
#     <th>Lastname</th>
#     <th>Age</th>
#   </tr>
#   <tr>
#     <td>John</td>
#     <td>Doe</td>
#     <td>50</td>
#   </tr>
#   <tr>
#     <td>Jane</td>
#     <td>Doe</td>
#     <td>45</td>
#   </tr>
# </table>
# Out:
# <table border="1">
#   <tr>
#     <th>Firstname</th>
#     <th>Lastname</th>
#     <th>Age</th>
#   </tr>
#   <tr>
#     <td>John</td>
#     <td>Doe</td>
#     <td>50</td>
#   </tr>
#   <tr>
#     <td>Jane</td>
#     <td>Doe</td>
#     <td>45</td>
#   </tr>
# </table>

# %%
# %%html
# <button onclick="alert('Hello, world!')">Click Me!</button>
# Out:
# <button onclick="alert('Hello, world!')">Click Me!</button>

# %% [markdown]
# ## %%javascript

# %%
# %%javascript
# alert('Hello, Jupyter!');

# %%
# %%html
# <select id="dataSelection">
#     <option value="data1">Dataset 1</option>
#     <option value="data2">Dataset 2</option>
#     <option value="data3">Dataset 3</option>
# </select>
# <div id="displayArea">Selected Dataset Information will appear here.</div>

# %%
# %%javascript
#
# // Function to update display based on selection
# function updateDisplay() {
#     var selection = document.getElementById('dataSelection').value;
#     var displayText = 'You selected ' + selection + ', displaying results...';
#     // This could be a place to dynamically update a chart or data visualization
#     document.getElementById('displayArea').innerText = displayText;
# }
#
# // Add event listener to dropdown
# document.getElementById('dataSelection').addEventListener('change', updateDisplay);
#
# // Initialize display
# updateDisplay();

# %% [markdown]
# ## %%latex

# %%
# %%latex
# \begin{align}
# \nabla \times \vec{\mathbf{B}} -\, \frac1{c} \, \frac{\partial\vec{\mathbf{E}}}{\partial t} & = \frac{4\pi}{c}\vec{\mathbf{j}} \\
# \nabla \cdot \vec{\mathbf{E}} & = 4 \pi \rho \\
# \nabla \times \vec{\mathbf{E}}\, +\, \frac1{c} \, \frac{\partial\vec{\mathbf{B}}}{\partial t} & = \vec{\mathbf{0}} \\
# \nabla \cdot \vec{\mathbf{B}} & = 0
# \end{align}
# Out:
# \begin{align}
# \nabla \times \vec{\mathbf{B}} -\, \frac1{c} \, \frac{\partial\vec{\mathbf{E}}}{\partial t} & = \frac{4\pi}{c}\vec{\mathbf{j}} \\
# \nabla \cdot \vec{\mathbf{E}} & = 4 \pi \rho \\
# \nabla \times \vec{\mathbf{E}}\, +\, \frac1{c} \, \frac{\partial\vec{\mathbf{B}}}{\partial t} & = \vec{\mathbf{0}} \\
# \nabla \cdot \vec{\mathbf{B}} & = 0
# \end{align}

# %% [markdown]
# # ChatGPT Extension
